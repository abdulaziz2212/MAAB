# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - **Task**: Plot the function $ f(x) = x^2 - 4x + 4 $ for $ x $ values between -10 and 10. Customize the plot with appropriate labels for the axes and a title.

# %%
def f_x(x):
    return (x-2)**2

x= np.linspace(-10,10,1000)
y=f_x(x)

plt.plot(x,y, label = '$f(x) = x^2- 4*x +4$')
plt.title("Parabola")
plt.xlabel("X")
plt.ylabel("Y", rotation = 0)
plt.legend()
plt.show()

# %% [markdown]
# - **Task**: Plot $ \sin(x) $ and $ \cos(x) $ on the same graph for $ x $ values ranging from 0 to $ 2\pi $. Use different line styles, markers, and colors to distinguish between the two functions. Add a legend.

# %%
plt.figure(figsize=(10,3))
x = np.linspace(0, 2*np.pi,100)

y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,linestyle = '--', label = "$sin(x)$",color = 'red', marker = 's')
plt.plot(x,y2, label = "$cos(x)$", color = 'green',linestyle =':', marker = 'o')
plt.legend()
plt.show()

# %% [markdown]
# **Task**: Create a 2x2 grid of subplots. In each subplot, plot:
#   - Top-left: $ f(x) = x^3 $
#   - Top-right: $ f(x) = \sin(x) $
#   - Bottom-left: $ f(x) = e^x $
#   - Bottom-right: $ f(x) = \log(x+1) $ (for $ x \geq 0 $)

# %%
x = np.linspace(-10,10,200)
y= x**3
fig, axes = plt.subplots(2, 2)  # 2x2 grid of subplots
axes[0, 0].plot(x,y)  # Top-left subplot
axes[0,0].set_title('$f(x) = x^3$')

y1 = np.sin(x)
axes[0,1].plot(x,y1)
axes[0,1].set_title('$f(x) = sin(x)$')

y2 = np.exp(x)
axes[1,0].plot(x,y2)
axes[1,0].set_title("$f(x) = e^x$")

y3 =np.log(x+1)
axes[1,1].plot(x,y3)
axes[1,1].set_title("$f(x) = log(x+1)$")
# Out:
# C:\Users\Victus\AppData\Local\Temp\ipykernel_15696\1338595422.py:15: RuntimeWarning: invalid value encountered in log
#   y3 =np.log(x+1)
# Text(0.5, 1.0, '$f(x) = log(x+1)$')

# %% [markdown]
# - **Task**: Create a scatter plot of 100 random points in a 2D space. The x and y values should be randomly generated from a uniform distribution between 0 and 10. Use different colors and markers for the points. Add a title, axis labels, and a grid.

# %%
x = np.random.uniform(0,10,100)
y = np.random.uniform(0,10,100)
sizes = np.abs(np.random.randn(50)) * 100

plt.figure(figsize=(6, 6))
plt.scatter(x, y, color="blue", alpha=0.6, edgecolors="black")
plt.colorbar()
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot of 100 Random Points")
plt.show()

# %% [markdown]
# - **Task**: Generate a random dataset of 1000 values sampled from a normal distribution (mean=0, std=1). Plot a histogram of the data with 30 bins. Add a title and axis labels. Adjust the transparency of the bars using the `alpha` parameter.

# %%
x = np.random.normal(0,1,1000)
plt.hist(x, bins = 30, color = 'blue', alpha = 0.7, edgecolor ='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Normally Distributed Data (μ=0, σ=1)")
# Out:
# Text(0.5, 1.0, 'Histogram of Normally Distributed Data (μ=0, σ=1)')

# %% [markdown]
# - **Task**: Create a 3D surface plot for the function $ f(x, y) = \cos(x^2 + y^2) $ over the range of $ x $ and $ y $ values from -5 to 5. Use a suitable colormap and add a colorbar. Set appropriate labels for the axes and title.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)

xx, yy = np.meshgrid(x, y)
zz = np.cos(xx**2 + yy**2)
ax.plot_surface(xx, yy, zz, cmap='viridis')

# %% [markdown]
# - **Task**: Create a vertical bar chart displaying the sales data for five different products: `['Product A', 'Product B', 'Product C', 'Product D', 'Product E']`. The sales values for each product are `[200, 150, 250, 175, 225]`. Customize the chart with a title, axis labels, and different bar colors.

# %%
categories = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
values = [200, 150, 250, 175, 225]
colors = ['red', 'blue', 'green', 'purple','black']

plt.bar(categories, values, color=colors, width=0.3)
plt.title('Sales')
plt.xlabel('Products')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# **Task**: Create a stacked bar chart that shows the contribution of three different categories (`'Category A'`, `'Category B'`, and `'Category C'`) over four time periods (`'T1'`, `'T2'`, `'T3'`, `'T4'`). Use sample data for each category at each time period. Customize the chart with a title, axis labels, and a legend.

# %%
# Define time periods and sample data for each category
time_periods = ['T1', 'T2', 'T3', 'T4']
category_a = np.array([5, 7, 6, 8])
category_b = np.array([3, 4, 5, 6])
category_c = np.array([2, 3, 4, 5])

# Create a stacked bar chart
plt.figure(figsize=(8, 6))
plt.bar(time_periods, category_a, label='Category A', color='blue')
plt.bar(time_periods, category_b, bottom=category_a, label='Category B', color='orange')
plt.bar(time_periods, category_c, bottom=category_a + category_b, label='Category C', color='green')

# Customize the chart
plt.xlabel("Time Periods")
plt.ylabel("Value")
plt.title("Stacked Bar Chart of Category Contributions")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.6)

# Show the plot
plt.show()
