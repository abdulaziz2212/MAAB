# %%
#import needed libraries
import sqlite3
import pandas as pd

#open a database file with sqlite and convert it to dataframe using pandas
with sqlite3.connect("chinook.db") as connection:
    df_employee = pd.read_sql("SELECT * FROM customers ",
    con = connection
    )

#display first 10 rows
df_employee.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
#converting json file to dataframe
with open('iris.json') as file:
    df_iris = pd.read_json(file)

#shape of dataframe
df_iris.shape

#column names
df_iris.columns
# Out:
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %%
#loading excel file to dataframe
df_titanic = pd.read_excel("titanic.xlsx")

#display first 5 rows
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#csv to dataframe
df_movie = pd.read_csv('movie.csv')

#random sample of 10 rows
df_movie.sample(10)
# Out:
#                 color         director_name  num_critic_for_reviews  duration  \
# 4689            Color           Tom Vaughan                   148.0     101.0
# 2221            Color   Mark Steven Johnson                    60.0     114.0
# 833             Color          Andy Tennant                   171.0     118.0
# 2308            Color        Kevin Reynolds                     9.0     107.0
# 4842  Black and White        John Reinhardt                     1.0      68.0
# 3470            Color  Francis Ford Coppola                   112.0      88.0
# 1184            Color            Peter Berg                   319.0     121.0
# 1521            Color      Richard Marquand                   197.0     134.0
# 2998            Color        Brendan Malloy                    37.0      89.0
# 3446            Color          Kevin Brodie                    25.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# ...

# %%
new_columns = [column.lower() for column in df_iris.columns]
df_iris.columns = new_columns
# df_iris
df_iris[['sepallength',"sepalwidth"]]
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
df_titanic
num_females = (df_titanic['Age']>30) & (df_titanic['Sex']=='female')
num_females.sum()
# Out:
# np.int64(103)

# %%
df_titanic
num_males = (df_titanic['Age']>30) & (df_titanic['Sex']=='male')
num_males.sum()
# Out:
# np.int64(202)

# %%
df_new = df_movie[df_movie['duration']>120]
df_new = df_new.sort_values(by='director_facebook_likes',ascending=False)
df_new
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 66    Color  Christopher Nolan                   645.0     152.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 120   Color  Christopher Nolan                   478.0     128.0
# 1222  Color  Christopher Nolan                   341.0     130.0
# 97    Color  Christopher Nolan                   642.0     148.0
# ...     ...                ...                     ...       ...
# 3357  Color                NaN                     9.0     142.0
# 3582  Color                NaN                    10.0     240.0
# 3799  Color                NaN                     2.0     199.0
# 4005  Color                NaN                     NaN     197.0
# 4031  Color                NaN                    10.0     173.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 66                    22000.0                 11000.0      Heath Ledger
# ...

# %%
for column in df_iris.columns:
    try:
        mean = df_iris[column].mean()
        median = df_iris[column].median()
        std = df_iris[column].std()

        print(f"{column} mean:{mean}, median: {median}, std: {std}")
    except Exception as e:
        print(e)
# Out:
# sepallength mean:5.843333333333334, median: 5.8, std: 0.828066127977863
# sepalwidth mean:3.0573333333333337, median: 3.0, std: 0.4358662849366982
# petallength mean:3.7580000000000005, median: 4.35, std: 1.7652982332594662
# petalwidth mean:1.1993333333333338, median: 1.3, std: 0.7622376689603467
# Could not convert string '...' to numeric

# %%
max_age = df_titanic['Age'].max()
min_age = df_titanic['Age'].min()
sum_age = df_titanic['Age'].sum()

# %%
directorWithMostLikes = df_movie.loc[(df_movie['director_facebook_likes']==df_movie['director_facebook_likes'].max()),["director_name"]]
print(directorWithMostLikes)

longest_films = df_movie.sort_values(by='duration',ascending=False).head()
longest_films
# Out:
#              director_name
# 3603  Joseph Gordon-Levitt
#       color        director_name  num_critic_for_reviews  duration  \
# 1694  Color                  NaN                    16.0     511.0
# 2436  Color                  NaN                   108.0     334.0
# 1487  Color      Taylor Hackford                    12.0     330.0
# 1134  Color       Michael Cimino                   102.0     325.0
# 3254  Color  Chatrichalerm Yukol                    31.0     300.0
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 1694                      NaN                    51.0
# 2436                      NaN                    30.0
# 1487                    138.0                   672.0
# 1134                    517.0                   678.0
# 3254                      6.0                     6.0
#
#                   actor_2_name  actor_1_facebook_likes      gross  \
# 1694  Ingvar Eggert Sigurðsson                   147.0        NaN
# ...

# %%
flights = pd.read_parquet('flights')
flights
df_selected = flights[['origin', 'dest', 'carrier']]
print(df_selected['dest'].unique())

# %%
print(df_selected.isnull().sum())
df_selected['price'].fillna(df_selected['price'].mean(), inplace=True)
